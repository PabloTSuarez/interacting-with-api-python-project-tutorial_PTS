# %% [markdown]
# # Explore here

# %%
import os
import pandas as pd
import seaborn as sns
from dotenv import load_dotenv
import spotipy
from spotipy.oauth2 import SpotifyOAuth

# load the .env file variables
load_dotenv()

client_id = os.environ.get("CLIENT_ID")
client_secret = os.environ.get("CLIENT_SECRET")

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id,client_secret=client_secret,redirect_uri='https://localhost'))

# %%
id_artista = '64tNsm6TnZe2zpcMVMOoHL'

respuesta = sp.artist_top_tracks(id_artista)

print(respuesta)
# Out:
# {'tracks': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64tNsm6TnZe2zpcMVMOoHL'}, 'href': 'https://api.spotify.com/v1/artists/64tNsm6TnZe2zpcMVMOoHL', 'id': '64tNsm6TnZe2zpcMVMOoHL', 'name': 'Alice In Chains', 'type': 'artist', 'uri': 'spotify:artist:64tNsm6TnZe2zpcMVMOoHL'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/5LbHbwejgZXRZAgzVAjkhj'}, 'href': 'https://api.spotify.com/v1/albums/5LbHbwejgZXRZAgzVAjkhj', 'id': '5LbHbwejgZXRZAgzVAjkhj', 'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2731f829ea9c2c7ffcec1a3c857', 'width': 640, 'height': 640}, {'url': 'https://i.scdn.co/image/ab67616d00001e021f829ea9c2c7ffcec1a3c857', 'width': 300, 'height': 300}, {'url': 'https://i.scdn.co/image/ab67616d000048511f829ea9c2c7ffcec1a3c857', 'width': 64, 'height': 64}], 'is_playable': True, 'name': 'Facelift', 'release_date': '1990-08-01', 'release_date_precision': 'day', 'total_tracks': 12, 'type': 'album', 'uri': 'spotify:album:5LbHbwejgZXRZAgzVAjkhj'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64tNsm6TnZe2zpcMVMOoHL'}, 'href': 'https://api.spotify.com/v1/artists/64tNsm6TnZe2zpcMVMOoHL', 'id': '64tNsm6TnZe2zpcMVMOoHL', 'name': 'Alice In Chains', 'type': 'artist', 'uri': 'spotify:artist:64tNsm6TnZe2zpcMVMOoHL'}], 'disc_number': 1, 'duration_ms': 285200, 'explicit': True, 'external_ids': {'isrc': 'USSM19000727'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/6gZVQvQZOFpzIy3HblJ20F'}, 'href': 'https://api.spotify.com/v1/tracks/6gZVQvQZOFpzIy3HblJ20F', 'id': '6gZVQvQZOFpzIy3HblJ20F', 'is_local': False, 'is_playable': True, 'name': 'Man in the Box', 'popularity': 79, 'preview_url': 'https://p.scdn.co/mp3-preview/68dbc11f83265b4edfe18c5d968a6de048a388dd?cid=db623ca837e84e1ebd5bf83b00aac956', 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:6gZVQvQZOFpzIy3HblJ20F'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64tNsm6TnZe2zpcMVMOoHL'}, 'href': 'https://api.spotify.com/v1/artists/64tNsm6TnZe2zpcMVMOoHL', 'id': '64tNsm6TnZe2zpcMVMOoHL', 'name': 'Alice In Chains', 'type': 'artist', 'uri': 'spotify:artist:64tNsm6TnZe2zpcMVMOoHL'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/58NXIEYqmq5dQHg9nV9duM'}, 'href': 'https://api.spotify.com/v1/albums/58NXIEYqmq5dQHg9nV9duM', 'id': '58NXIEYqmq5dQHg9nV9duM', 'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2731cd131e5e9ad887ad8c1ecb7', 'width': 640, 'height': 640}, {'url': 'https://i.scdn.co/image/ab67616d00001e021cd131e5e9ad887ad8c1ecb7', 'width': 300, 'height': 300}, {'url': 'https://i.scdn.co/image/ab67616d000048511cd131e5e9ad887ad8c1ecb7', 'width': 64, 'height': 64}], 'is_playable': True, 'name': 'Dirt (2022 Remaster)', 'release_date': '1992-09-29', 'release_date_precision': 'day', 'total_tracks': 13, 'type': 'album', 'uri': 'spotify:album:58NXIEYqmq5dQHg9nV9duM'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64tNsm6TnZe2zpcMVMOoHL'}, 'href': 'https://api.spotify.com/v1/artists/64tNsm6TnZe2zpcMVMOoHL', 'id': '64tNsm6TnZe2zpcMVMOoHL', 'name': 'Alice In Chains', 'type': 'artist', 'uri': 'spotify:artist:64tNsm6TnZe2zpcMVMOoHL'}], 'disc_number': 1, 'duration_ms': 206773, 'explicit': False, 'external_ids': {'isrc': 'USSM19200805'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/5sFDReWLrZHLFZFjHsjUTS'}, 'href': 'https://api.spotify.com/v1/tracks/5sFDReWLrZHLFZFjHsjUTS', 'id': '5sFDReWLrZHLFZFjHsjUTS', 'is_local': False, 'is_playable': True, 'name': 'Would? (2022 Remaster)', 'popularity': 77, 'preview_url': 'https://p.scdn.co/mp3-preview/1343c561e5b037af86835365ee0bb9718c20ae11?cid=db623ca837e84e1ebd5bf83b00aac956', 'track_number': 13, 'type': 'track', 'uri': 'spotify:track:5sFDReWLrZHLFZFjHsjUTS'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64tNsm6TnZe2zpcMVMOoHL'}, 'hr ...
